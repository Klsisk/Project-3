# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in salary csv
salary_df = pd.read_csv("static/data/salary.csv")
salary_df.head(10)
# Out:
#    id             player team    salary
# 0   1      Stephen Curry  GSW  34682550
# 1   2       LeBron James  CLE  33285709
# 2   3       Paul Millsap  DEN  31269231
# 3   4     Gordon Hayward  BOS  29727900
# 4   5      Blake Griffin  DET  29512900
# 5   6         Kyle Lowry  TOR  28703704
# 6   7  Russell Westbrook  OKC  28530608
# 7   8        Mike Conley  MEM  28530608
# 8   9       James Harden  HOU  28299399
# 9  10      DeMar DeRozan  TOR  27739975

# %%
# Sort by ascending salaries
sort_salary = salary_df.sort_values('salary',ascending=False)
sort_salary.head(11)
# Out:
#     id             player team    salary
# 0    1      Stephen Curry  GSW  34682550
# 1    2       LeBron James  CLE  33285709
# 2    3       Paul Millsap  DEN  31269231
# 3    4     Gordon Hayward  BOS  29727900
# 4    5      Blake Griffin  DET  29512900
# 5    6         Kyle Lowry  TOR  28703704
# 6    7  Russell Westbrook  OKC  28530608
# 7    8        Mike Conley  MEM  28530608
# 8    9       James Harden  HOU  28299399
# 9   10      DeMar DeRozan  TOR  27739975
# 10  11         Al Horford  BOS  27734405

# %%
# Generate a bar plot showing top 10 player salaries and their teams
# Set x_axis, y_axis, tick locations, and colors for bars
y_axis = ['0', 'MEM', 'OKC', 'TOR','DET', 'BOS', 'DEN', 'CLE', 'GSW']
x_axis = ['0', '28530608', '28530608', '28703704', '29512900', '29727900', '31269231', '33285709', '34682550']
color= ["navy", "red", "navy", "red", "navy", "red", "navy", "red"]

# Show the graph
plt.barh(y_axis, x_axis, color=color, align="center")
plt.xticks(rotation="45", fontsize=7)

# Set a Title and labels
plt.title('Top 8 Player Salaries and Their Teams')
plt.ylabel('Teams')
plt.xlabel('Player Salaries')

# Show the graph
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Load in allstar csv
allstar_df = pd.read_csv("static/data/allstar1.csv")
allstar_df.head(10)
# Out:
#    Id           player position team
# 0  26      Dwyane Wade       SG  MIA
# 1  27      Paul George       GF  IND
# 2  28  Carmelo Anthony        F  NYK
# 3  29       Kyle Lowry       PG  TOR
# 4  30     Jimmy Butler       GF  CHI
# 5  31    DeMar DeRozan       GF  TOR
# 6  32     Paul Millsap       FC  ATL
# 7  33   Andre Drummond        C  DET
# 8  34       Chris Bosh       PF  MIA
# 9  35        John Wall       PG  WAS

# %%
total_teams = allstar_df["team"].value_counts()
total_teams
# Out:
# MIA    28
# LAL    25
# BOS    25
# SAS    24
# HOU    19
# DAL    18
# PHX    18
# ATL    17
# DET    15
# ORL    14
# IND    14
# TOR    14
# LAC    13
# CLE    13
# MIN    12
# WAS    12
# NOP    12
# OKC    12
# NJN    12
# PHI    11
# CHI    11
# POR    10
# NYK    10
# SAC    10
# DEN     9
# SEA     8
# UTA     8
# GSW     7
# MEM     5
# MIL     4
# BKN     2
# CBO     1
# CHA     1
# Name: team, dtype: int64

# %%
# Generate a bar plot showing top 10 teams with most allstars
# Set x_axis, y_axis, tick locations, and colors for bars
x_axis = ['0', 'ORL','DET', 'ATL', 'PHX', 'DAL', 'HOU', 'SAS', 'BOS', 'LAL', 'MIA']
y_axis = ['0', '14', '15', '17', '18', '18', '19', '24', '25', '25', '28']
color= ["navy", "red", "navy", "red", "navy", "red", "navy", "red"]

plt.figure(figsize=(6,3))
plt.bar (x_axis,y_axis, color=color, align="center")
plt.xticks(rotation="45", fontsize=8)

# Set a Title and labels
plt.title('Top Teams With Most All-Stars')
plt.xlabel("Teams")
plt.ylabel("Number of Players")

# Show the graph
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
