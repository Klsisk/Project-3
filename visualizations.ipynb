# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in salary csv
salary_df = pd.read_csv("static/data/salary.csv")
salary_df.head()
# Out:
#    id          player team    salary
# 0   1   Stephen Curry  GSW  34682550
# 1   2    LeBron James  CLE  33285709
# 2   3    Paul Millsap  DEN  31269231
# 3   4  Gordon Hayward  BOS  29727900
# 4   5   Blake Griffin  DET  29512900

# %%
# Sort by ascending salaries
sort_salary = salary_df.sort_values('salary',ascending=False)
sort_salary.head(10)
# Out:
#       id          player team    salary
# 0      1   Stephen Curry  GSW  34682550
# 573  574   Stephen Curry  GSW  34682550
# 574  575    LeBron James  CLE  33285709
# 1      2    LeBron James  CLE  33285709
# 575  576    Paul Millsap  DEN  31269231
# 2      3    Paul Millsap  DEN  31269231
# 576  577  Gordon Hayward  BOS  29727900
# 3      4  Gordon Hayward  BOS  29727900
# 577  578   Blake Griffin  DET  29512900
# 4      5   Blake Griffin  DET  29512900

# %%
y_axis = ['0', 'DET', 'BOS', 'DEN', 'CLE', 'GSW']
x_axis = ['0', '29512900', '29727900', '31269231', '33285709', '34682550']

plt.barh(y_axis,x_axis)
plt.title('Top 5 Player Salaries and Their Teams')
plt.ylabel('Teams')
plt.xlabel('Player Salaries')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Load in allstar csv
allstar_df = pd.read_csv("static/data/allstar1.csv")
allstar_df.head()
# Out:
#    Id           player position team
# 0  26      Dwyane Wade       SG  MIA
# 1  27      Paul George       GF  IND
# 2  28  Carmelo Anthony        F  NYK
# 3  29       Kyle Lowry       PG  TOR
# 4  30     Jimmy Butler       GF  CHI

# %%
total_teams = allstar_df["team"].value_counts()
total_teams
# Out:
# MIA    28
# LAL    25
# BOS    25
# SAS    24
# HOU    19
# DAL    18
# PHX    18
# ATL    17
# DET    15
# ORL    14
# TOR    14
# IND    14
# LAC    13
# CLE    13
# NOP    12
# OKC    12
# WAS    12
# NJN    12
# MIN    12
# CHI    11
# PHI    11
# NYK    10
# POR    10
# SAC    10
# DEN     9
# SEA     8
# UTA     8
# GSW     7
# MEM     5
# MIL     4
# BKN     2
# CHA     1
# CBO     1
# Name: team, dtype: int64

# %%
xaxis = ['0', 'ORL','DET', 'ATL', 'PHX', 'DAL', 'HOU', 'SAS', 'BOS', 'LAL', 'MIA']
yaxis = ['0', '14', '15', '17', '18', '18', '19', '24', '25', '25', '28']

plt.figure(figsize=(6,3))
plt.bar (xaxis,yaxis, color="b", alpha=0.50, align="center")
plt.xticks(rotation="vertical", fontsize=7)

# Set a Title and labels
plt.title('Teams With Most All-Stars')
plt.xlabel("Teams")
plt.ylabel("Number of Players")

# Show the graph
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
